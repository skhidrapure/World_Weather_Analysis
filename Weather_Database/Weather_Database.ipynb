# %%
import numpy as np
from citipy import citipy
from config import weather_api_key
import time
import requests
from datetime import datetime
import pandas as pd

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather['weather'][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except Exception as e:
        print("City not found. Skipping...", e)
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | severo-kurilsk
# Processing Record 2 of Set 1 | vanimo
# Processing Record 3 of Set 1 | harper
# Processing Record 4 of Set 1 | iqaluit
# Processing Record 5 of Set 1 | ostrovnoy
# Processing Record 6 of Set 1 | chumikan
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | praia da vitoria
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | tsihombe
# City not found. Skipping... 'coord'
# Processing Record 12 of Set 1 | comodoro rivadavia
# Processing Record 13 of Set 1 | airai
# Processing Record 14 of Set 1 | zalantun
# Processing Record 15 of Set 1 | klaksvik
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | tura
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping... 'coord'
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | bethel
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | songjianghe
# Processing Record 24 of Set 1 | kudahuvadhoo
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | upernavik
# Processing Record 28 of Set 1 | torbay
# Processing Record 29 of Set 1 | arman
# Processing Record 30 of Set 1 | beloha
# Processing Record 31 of Set 1 | vardo
# Processing Record 32 of Set 1 | bambous virieux
# Processing Record 33 of Set 1 | sabang
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | sept-iles
# Processing Record 36 of Set 1 | tamandare
# Processing Record 37 of Set 1 | halifax
# Processing Record 38 of Set 1 | san patricio
# Processing Record 39 of Set 1 | tabiauea
# City not found. Skipping... 'coord'
# Processing Record 40 of Set 1 | geresk
# City not found. Skipping... 'coord'
# Processing Record 41 of Set 1 | tabou
# Processing Record 42 of Set 1 | kaitangata
# Processing Record 43 of Set 1 | sao filipe
# Processing Record 44 of Set 1 | khatanga
# Processing Record 45 of Set 1 | faya
# Processing Record 46 of Set 1 | longyearbyen
# Processing Record 47 of Set 1 | nikolskoye
# Processing Record 48 of Set 1 | yar-sale
# Processing Record 49 of Set 1 | nizhneyansk
# City not found. Skipping... 'coord'
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | vestmannaeyjar
# Processing Record 2 of Set 2 | nanortalik
# Processing Record 3 of Set 2 | new norfolk
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | ambulu
# Processing Record 7 of Set 2 | thompson
# Processing Record 8 of Set 2 | visnes
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | tiksi
# Processing Record 11 of Set 2 | jamestown
# Processing Record 12 of Set 2 | shelburne
# Processing Record 13 of Set 2 | tuktoyaktuk
# Processing Record 14 of Set 2 | zharkent
# Processing Record 15 of Set 2 | karratha
# Processing Record 16 of Set 2 | kyotera
# Processing Record 17 of Set 2 | mashhad
# Processing Record 18 of Set 2 | amderma
# City not found. Skipping... 'coord'
# Processing Record 19 of Set 2 | aasiaat
# Processing Record 20 of Set 2 | richards bay
# Processing Record 21 of Set 2 | asau
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | tasiilaq
# Processing Record 24 of Set 2 | guarapari
# Processing Record 25 of Set 2 | shirokiy
# Processing Record 26 of Set 2 | kangaatsiaq
# Processing Record 27 of Set 2 | avarua
# Processing Record 28 of Set 2 | saint-philippe
# Processing Record 29 of Set 2 | ushuaia
# Processing Record 30 of Set 2 | nageshwari
# Processing Record 31 of Set 2 | port elizabeth
# Processing Record 32 of Set 2 | jabiru
# City not found. Skipping... 'coord'
# Processing Record 33 of Set 2 | prestea
# Processing Record 34 of Set 2 | ust-nera
# Processing Record 35 of Set 2 | tulum
# Processing Record 36 of Set 2 | la ronge
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | ak-dovurak
# Processing Record 39 of Set 2 | hasaki
# Processing Record 40 of Set 2 | east london
# Processing Record 41 of Set 2 | puerto ayora
# Processing Record 42 of Set 2 | birjand
# Processing Record 43 of Set 2 | mitsamiouli
# Processing Record 44 of Set 2 | illoqqortoormiut
# City not found. Skipping... 'coord'
# Processing Record 45 of Set 2 | talcahuano
# Processing Record 46 of Set 2 | mandalgovi
# Processing Record 47 of Set 2 | mys shmidta
# City not found. Skipping... 'coord'
# Processing Record 48 of Set 2 | talnakh
# Processing Record 49 of Set 2 | aflu
# City not found. Skipping... 'coord'
# Processing Record 50 of Set 2 | iwanai
# Processing Record 1 of Set 3 | bowen
# Processing Record 2 of Set 3 | haines junction
# Processing Record 3 of Set 3 | attawapiskat
# City not found. Skipping... 'coord'
# Processing Record 4 of Set 3 | sur
# Processing Record 5 of Set 3 | sentyabrskiy
# City not found. Skipping... 'coord'
# Processing Record 6 of Set 3 | inhambane
# Processing Record 7 of Set 3 | talara
# Processing Record 8 of Set 3 | rocha
# Processing Record 9 of Set 3 | ayame
# Processing Record 10 of Set 3 | buraydah
# Processing Record 11 of Set 3 | saint-leu
# Processing Record 12 of Set 3 | arraial do cabo
# Processing Record 13 of Set 3 | taoudenni
# Processing Record 14 of Set 3 | san quintin
# Processing Record 15 of Set 3 | kitovo
# Processing Record 16 of Set 3 | mount isa
# Processing Record 17 of Set 3 | matata
# Processing Record 18 of Set 3 | bengkulu
# Processing Record 19 of Set 3 | saint-louis
# Processing Record 20 of Set 3 | vaini
# Processing Record 21 of Set 3 | miguel calmon
# Processing Record 22 of Set 3 | qaanaaq
# Processing Record 23 of Set 3 | elizabeth city
# Processing Record 24 of Set 3 | soddy-daisy
# Processing Record 25 of Set 3 | beidao
# Processing Record 26 of Set 3 | pedra azul
# Processing Record 27 of Set 3 | ust-kamchatsk
# City not found. Skipping... 'coord'
# Processing Record 28 of Set 3 | umzimvubu
# City not found. Skipping... 'coord'
# Processing Record 29 of Set 3 | severnyy
# Processing Record 30 of Set 3 | castro
# Processing Record 31 of Set 3 | cherskiy
# Processing Record 32 of Set 3 | butaritari
# Processing Record 33 of Set 3 | chuy
# Processing Record 34 of Set 3 | kavieng
# Processing Record 35 of Set 3 | pemangkat
# Processing Record 36 of Set 3 | general pico
# Processing Record 37 of Set 3 | lagoa
# Processing Record 38 of Set 3 | lusambo
# Processing Record 39 of Set 3 | obando
# Processing Record 40 of Set 3 | kendari
# Processing Record 41 of Set 3 | melito di porto salvo
# Processing Record 42 of Set 3 | grindavik
# Processing Record 43 of Set 3 | clyde river
# Processing Record 44 of Set 3 | mezen
# Processing Record 45 of Set 3 | bloomingdale
# Processing Record 46 of Set 3 | belushya guba
# City not found. Skipping... 'coord'
# Processing Record 47 of Set 3 | saint george
# Processing Record 48 of Set 3 | ocos
# Processing Record 49 of Set 3 | chokurdakh
# Processing Record 50 of Set 3 | lake havasu city
# Processing Record 1 of Set 4 | isetskoye
# Processing Record 2 of Set 4 | te anau
# Processing Record 3 of Set 4 | agadir
# Processing Record 4 of Set 4 | acopiara
# Processing Record 5 of Set 4 | leningradskiy
# Processing Record 6 of Set 4 | marfino
# Processing Record 7 of Set 4 | guerrero negro
# Processing Record 8 of Set 4 | santiago del estero
# Processing Record 9 of Set 4 | rapid city
# Processing Record 10 of Set 4 | huarmey
# Processing Record 11 of Set 4 | taltal
# Processing Record 12 of Set 4 | japura
# Processing Record 13 of Set 4 | faanui
# Processing Record 14 of Set 4 | fairbanks
# Processing Record 15 of Set 4 | satellite beach
# Processing Record 16 of Set 4 | lebu
# Processing Record 17 of Set 4 | sobolevo
# Processing Record 18 of Set 4 | provideniya
# Processing Record 19 of Set 4 | pacific grove
# Processing Record 20 of Set 4 | trelew
# Processing Record 21 of Set 4 | vylgort
# City not found. Skipping... 'coord'
# Processing Record 22 of Set 4 | warqla
# City not found. Skipping... 'coord'
# Processing Record 23 of Set 4 | geraldton
# Processing Record 24 of Set 4 | ous
# Processing Record 25 of Set 4 | susangerd
# Processing Record 26 of Set 4 | mercedes
# Processing Record 27 of Set 4 | iquitos
# Processing Record 28 of Set 4 | wad madani
# Processing Record 29 of Set 4 | bolungarvik
# City not found. Skipping... 'coord'
# Processing Record 30 of Set 4 | tarudant
# City not found. Skipping... 'coord'
# Processing Record 31 of Set 4 | columbus
# Processing Record 32 of Set 4 | sistranda
# Processing Record 33 of Set 4 | lompoc
# Processing Record 34 of Set 4 | puerto colombia
# Processing Record 35 of Set 4 | lavrentiya
# Processing Record 36 of Set 4 | male
# Processing Record 37 of Set 4 | raga
# Processing Record 38 of Set 4 | hithadhoo
# Processing Record 39 of Set 4 | gravdal
# Processing Record 40 of Set 4 | buchanan
# Processing Record 41 of Set 4 | port hedland
# Processing Record 42 of Set 4 | saleaula
# City not found. Skipping... 'coord'
# Processing Record 43 of Set 4 | kidal
# Processing Record 44 of Set 4 | kodiak
# Processing Record 45 of Set 4 | betsiamites
# Processing Record 46 of Set 4 | cabo rojo
# Processing Record 47 of Set 4 | sidi ali
# Processing Record 48 of Set 4 | camrose
# Processing Record 49 of Set 4 | manbij
# Processing Record 50 of Set 4 | olinda
# Processing Record 1 of Set 5 | atbasar
# Processing Record 2 of Set 5 | esperance
# Processing Record 3 of Set 5 | saskylakh
# Processing Record 4 of Set 5 | birao
# Processing Record 5 of Set 5 | yaan
# Processing Record 6 of Set 5 | mahebourg
# Processing Record 7 of Set 5 | meulaboh
# Processing Record 8 of Set 5 | corinto
# Processing Record 9 of Set 5 | salym
# Processing Record 10 of Set 5 | khrebtovaya
# Processing Record 11 of Set 5 | toliary
# City not found. Skipping... 'coord'
# Processing Record 12 of Set 5 | bolonchen
# City not found. Skipping... 'coord'
# Processing Record 13 of Set 5 | cabo san lucas
# Processing Record 14 of Set 5 | havelock
# Processing Record 15 of Set 5 | mocuba
# Processing Record 16 of Set 5 | luderitz
# Processing Record 17 of Set 5 | kuna
# Processing Record 18 of Set 5 | hadejia
# Processing Record 19 of Set 5 | hilo
# Processing Record 20 of Set 5 | port hawkesbury
# Processing Record 21 of Set 5 | ler
# Processing Record 22 of Set 5 | hamilton
# Processing Record 23 of Set 5 | benguela
# Processing Record 24 of Set 5 | dikson
# Processing Record 25 of Set 5 | lucapa
# Processing Record 26 of Set 5 | norman wells
# Processing Record 27 of Set 5 | krasnoselkup
# Processing Record 28 of Set 5 | alice springs
# Processing Record 29 of Set 5 | saldanha
# Processing Record 30 of Set 5 | djenne
# Processing Record 31 of Set 5 | apiai
# Processing Record 32 of Set 5 | shimoda
# Processing Record 33 of Set 5 | guilin
# Processing Record 34 of Set 5 | rzhaksa
# Processing Record 35 of Set 5 | saint-augustin
# Processing Record 36 of Set 5 | rock springs
# Processing Record 37 of Set 5 | leigh
# Processing Record 38 of Set 5 | deputatskiy
# Processing Record 39 of Set 5 | ayan
# Processing Record 40 of Set 5 | kaspiysk
# Processing Record 41 of Set 5 | makushino
# Processing Record 42 of Set 5 | hofn
# Processing Record 43 of Set 5 | pilar
# Processing Record 44 of Set 5 | ust-uda
# Processing Record 45 of Set 5 | palana
# Processing Record 46 of Set 5 | sayyan
# Processing Record 47 of Set 5 | moose factory
# Processing Record 48 of Set 5 | zachagansk
# City not found. Skipping... 'coord'
# Processing Record 49 of Set 5 | samusu
# City not found. Skipping... 'coord'
# Processing Record 50 of Set 5 | pinerolo
# Processing Record 1 of Set 6 | veraval
# Processing Record 2 of Set 6 | rayevskiy
# Processing Record 3 of Set 6 | san-pedro
# Processing Record 4 of Set 6 | raudeberg
# Processing Record 5 of Set 6 | ngong
# Processing Record 6 of Set 6 | cidreira
# Processing Record 7 of Set 6 | nadym
# Processing Record 8 of Set 6 | maragogi
# Processing Record 9 of Set 6 | duzici
# City not found. Skipping... 'coord'
# Processing Record 10 of Set 6 | waingapu
# Processing Record 11 of Set 6 | callaway
# Processing Record 12 of Set 6 | barentsburg
# City not found. Skipping... 'coord'
# Processing Record 13 of Set 6 | egvekinot
# Processing Record 14 of Set 6 | kamyaran
# Processing Record 15 of Set 6 | kargasok
# Processing Record 16 of Set 6 | alexandria
# Processing Record 17 of Set 6 | pisco
# Processing Record 18 of Set 6 | sitka
# Processing Record 19 of Set 6 | kibre mengist
# Processing Record 20 of Set 6 | chicama
# Processing Record 21 of Set 6 | soyo
# Processing Record 22 of Set 6 | dzilam gonzalez
# Processing Record 23 of Set 6 | balkanabat
# Processing Record 24 of Set 6 | palabuhanratu
# City not found. Skipping... 'coord'
# Processing Record 25 of Set 6 | poum
# Processing Record 26 of Set 6 | havoysund
# Processing Record 27 of Set 6 | isangel
# Processing Record 28 of Set 6 | fougamou
# Processing Record 29 of Set 6 | byron bay
# Processing Record 30 of Set 6 | novovarshavka
# Processing Record 31 of Set 6 | banda aceh
# Processing Record 32 of Set 6 | grand gaube
# Processing Record 33 of Set 6 | sofiysk
# City not found. Skipping... 'coord'
# Processing Record 34 of Set 6 | hendijan
# City not found. Skipping... 'coord'
# Processing Record 35 of Set 6 | ponta delgada
# Processing Record 36 of Set 6 | vila
# Processing Record 37 of Set 6 | coquimbo
# Processing Record 38 of Set 6 | lahaina
# Processing Record 39 of Set 6 | yulara
# Processing Record 40 of Set 6 | basco
# Processing Record 41 of Set 6 | ponta do sol
# Processing Record 42 of Set 6 | shingu
# Processing Record 43 of Set 6 | almenara
# Processing Record 44 of Set 6 | den helder
# Processing Record 45 of Set 6 | senanga
# Processing Record 46 of Set 6 | christchurch
# Processing Record 47 of Set 6 | tuatapere
# Processing Record 48 of Set 6 | kalmunai
# Processing Record 49 of Set 6 | jumla
# Processing Record 50 of Set 6 | halalo
# City not found. Skipping... 'coord'
# Processing Record 1 of Set 7 | zambezi
# Processing Record 2 of Set 7 | road town
# Processing Record 3 of Set 7 | bargal
# City not found. Skipping... 'coord'
# Processing Record 4 of Set 7 | tiznit
# Processing Record 5 of Set 7 | jandaia do sul
# Processing Record 6 of Set 7 | lolua
# City not found. Skipping... 'coord'
# Processing Record 7 of Set 7 | zalari
# Processing Record 8 of Set 7 | rungata
# City not found. Skipping... 'coord'
# Processing Record 9 of Set 7 | ozgon
# City not found. Skipping... 'coord'
# Processing Record 10 of Set 7 | constitucion
# Processing Record 11 of Set 7 | ushumun
# Processing Record 12 of Set 7 | salta
# Processing Record 13 of Set 7 | college
# Processing Record 14 of Set 7 | alta floresta
# Processing Record 15 of Set 7 | muncar
# Processing Record 16 of Set 7 | natal
# Processing Record 17 of Set 7 | kloulklubed
# Processing Record 18 of Set 7 | hualmay
# Processing Record 19 of Set 7 | labuhan
# Processing Record 20 of Set 7 | sarkhej
# Processing Record 21 of Set 7 | baghdad
# Processing Record 22 of Set 7 | carnarvon
# Processing Record 23 of Set 7 | souillac
# Processing Record 24 of Set 7 | nizhniy baskunchak
# Processing Record 25 of Set 7 | dunedin
# Processing Record 26 of Set 7 | lazaro cardenas
# Processing Record 27 of Set 7 | imeni poliny osipenko
# Processing Record 28 of Set 7 | smoky lake
# Processing Record 29 of Set 7 | acarau
# Processing Record 30 of Set 7 | celestun
# Processing Record 31 of Set 7 | srednekolymsk
# Processing Record 32 of Set 7 | aykhal
# Processing Record 33 of Set 7 | cockburn town
# Processing Record 34 of Set 7 | paamiut
# Processing Record 35 of Set 7 | okhotsk
# Processing Record 36 of Set 7 | kirensk
# Processing Record 37 of Set 7 | pergamino
# Processing Record 38 of Set 7 | sagaing
# Processing Record 39 of Set 7 | nemuro
# Processing Record 40 of Set 7 | goderich
# Processing Record 41 of Set 7 | boysun
# Processing Record 42 of Set 7 | narsaq
# Processing Record 43 of Set 7 | qaqortoq
# Processing Record 44 of Set 7 | kyzyl-suu
# Processing Record 45 of Set 7 | sao felix do xingu
# Processing Record 46 of Set 7 | haljala
# Processing Record 47 of Set 7 | antalaha
# Processing Record 48 of Set 7 | abaza
# Processing Record 49 of Set 7 | ticusul
# City not found. Skipping... 'coord'
# Processing Record 50 of Set 7 | launceston
# Processing Record 1 of Set 8 | srandakan
# Processing Record 2 of Set 8 | orlik
# Processing Record 3 of Set 8 | caravelas
# Processing Record 4 of Set 8 | pevek
# Processing Record 5 of Set 8 | port hardy
# Processing Record 6 of Set 8 | vao
# Processing Record 7 of Set 8 | skalistyy
# City not found. Skipping... 'coord'
# Processing Record 8 of Set 8 | umm lajj
# Processing Record 9 of Set 8 | martapura
# Processing Record 10 of Set 8 | cavalcante
# Processing Record 11 of Set 8 | puro
# Processing Record 12 of Set 8 | salalah
# Processing Record 13 of Set 8 | poya
# Processing Record 14 of Set 8 | namie
# Processing Record 15 of Set 8 | chagda
# City not found. Skipping... 'coord'
# Processing Record 16 of Set 8 | fare
# Processing Record 17 of Set 8 | manono
# Processing Record 18 of Set 8 | tezu
# Processing Record 19 of Set 8 | vila velha
# Processing Record 20 of Set 8 | agirish
# Processing Record 21 of Set 8 | lanzhou
# Processing Record 22 of Set 8 | gubskaya
# Processing Record 23 of Set 8 | ahuimanu
# Processing Record 24 of Set 8 | west wendover
# Processing Record 25 of Set 8 | zhigansk
# Processing Record 26 of Set 8 | urdzhar
# City not found. Skipping... 'coord'
# Processing Record 27 of Set 8 | meridian
# Processing Record 28 of Set 8 | berwick
# Processing Record 29 of Set 8 | sorland
# Processing Record 30 of Set 8 | hirara
# Processing Record 31 of Set 8 | parvatipuram
# Processing Record 32 of Set 8 | esmeraldas
# Processing Record 33 of Set 8 | san carlos de bariloche
# Processing Record 34 of Set 8 | hurghada
# Processing Record 35 of Set 8 | macherla
# Processing Record 36 of Set 8 | berlevag
# Processing Record 37 of Set 8 | khuzdar
# Processing Record 38 of Set 8 | maua
# Processing Record 39 of Set 8 | jieshi
# Processing Record 40 of Set 8 | asfi
# Processing Record 41 of Set 8 | la palma
# Processing Record 42 of Set 8 | port lincoln
# Processing Record 43 of Set 8 | ryotsu
# Processing Record 44 of Set 8 | nuuk
# Processing Record 45 of Set 8 | tumannyy
# City not found. Skipping... 'coord'
# Processing Record 46 of Set 8 | laguna
# Processing Record 47 of Set 8 | dingle
# Processing Record 48 of Set 8 | melton mowbray
# Processing Record 49 of Set 8 | codrington
# Processing Record 50 of Set 8 | luanda
# Processing Record 1 of Set 9 | camapua
# Processing Record 2 of Set 9 | barsi
# Processing Record 3 of Set 9 | rio tercero
# Processing Record 4 of Set 9 | akom
# Processing Record 5 of Set 9 | alunitdag
# City not found. Skipping... 'coord'
# Processing Record 6 of Set 9 | broken hill
# Processing Record 7 of Set 9 | kutum
# Processing Record 8 of Set 9 | margate
# Processing Record 9 of Set 9 | victoria
# Processing Record 10 of Set 9 | hami
# Processing Record 11 of Set 9 | marzuq
# Processing Record 12 of Set 9 | kant
# Processing Record 13 of Set 9 | prince rupert
# Processing Record 14 of Set 9 | rock sound
# Processing Record 15 of Set 9 | mingyue
# Processing Record 16 of Set 9 | arlit
# Processing Record 17 of Set 9 | baruun-urt
# Processing Record 18 of Set 9 | pokaran
# Processing Record 19 of Set 9 | fortuna
# Processing Record 20 of Set 9 | san cristobal
# Processing Record 21 of Set 9 | esso
# Processing Record 22 of Set 9 | azangaro
# Processing Record 23 of Set 9 | muli
# Processing Record 24 of Set 9 | los llanos de aridane
# Processing Record 25 of Set 9 | trinidad
# Processing Record 26 of Set 9 | kingman
# Processing Record 27 of Set 9 | ha tinh
# Processing Record 28 of Set 9 | high level
# Processing Record 29 of Set 9 | ancud
# Processing Record 30 of Set 9 | dali
# Processing Record 31 of Set 9 | kamenskoye
# City not found. Skipping... 'coord'
# Processing Record 32 of Set 9 | portland
# Processing Record 33 of Set 9 | santo domingo
# Processing Record 34 of Set 9 | munchberg
# Processing Record 35 of Set 9 | cap malheureux
# Processing Record 36 of Set 9 | lukovetskiy
# Processing Record 37 of Set 9 | solovetskiy
# City not found. Skipping... 'coord'
# Processing Record 38 of Set 9 | alugan
# Processing Record 39 of Set 9 | viligili
# City not found. Skipping... 'coord'
# Processing Record 40 of Set 9 | constanza
# Processing Record 41 of Set 9 | gardiner
# Processing Record 42 of Set 9 | marawi
# Processing Record 43 of Set 9 | bam
# Processing Record 44 of Set 9 | glendive
# Processing Record 45 of Set 9 | mae ramat
# Processing Record 46 of Set 9 | rosetta
# Processing Record 47 of Set 9 | namibe
# Processing Record 48 of Set 9 | zhaodong
# Processing Record 49 of Set 9 | pitimbu
# Processing Record 50 of Set 9 | luklukan
# Processing Record 1 of Set 10 | xiamen
# Processing Record 2 of Set 10 | broome
# Processing Record 3 of Set 10 | scottsburgh
# City not found. Skipping... 'coord'
# Processing Record 4 of Set 10 | itacarambi
# Processing Record 5 of Set 10 | caraballeda
# Processing Record 6 of Set 10 | leh
# Processing Record 7 of Set 10 | passy
# Processing Record 8 of Set 10 | mehamn
# Processing Record 9 of Set 10 | oster
# Processing Record 10 of Set 10 | azuqueca de henares
# Processing Record 11 of Set 10 | gobabis
# Processing Record 12 of Set 10 | saurimo
# Processing Record 13 of Set 10 | clarence town
# Processing Record 14 of Set 10 | mount gambier
# Processing Record 15 of Set 10 | kruisfontein
# Processing Record 16 of Set 10 | touros
# Processing Record 17 of Set 10 | kizner
# Processing Record 18 of Set 10 | bolobo
# Processing Record 19 of Set 10 | balky
# Processing Record 20 of Set 10 | turba
# Processing Record 21 of Set 10 | lugovskoy
# Processing Record 22 of Set 10 | aklavik
# Processing Record 23 of Set 10 | pochutla
# Processing Record 24 of Set 10 | sfantu gheorghe
# Processing Record 25 of Set 10 | abu zabad
# Processing Record 26 of Set 10 | la orilla
# Processing Record 27 of Set 10 | san jose
# Processing Record 28 of Set 10 | bandarbeyla
# Processing Record 29 of Set 10 | flinders
# Processing Record 30 of Set 10 | sechura
# Processing Record 31 of Set 10 | vangaindrano
# Processing Record 32 of Set 10 | mar del plata
# Processing Record 33 of Set 10 | culebra
# Processing Record 34 of Set 10 | pacifica
# Processing Record 35 of Set 10 | trat
# Processing Record 36 of Set 10 | dzhusaly
# City not found. Skipping... 'coord'
# Processing Record 37 of Set 10 | saint-pierre
# Processing Record 38 of Set 10 | puerto rondon
# Processing Record 39 of Set 10 | orapa
# Processing Record 40 of Set 10 | puerto leguizamo
# Processing Record 41 of Set 10 | svetlyy
# Processing Record 42 of Set 10 | madimba
# Processing Record 43 of Set 10 | galveston
# Processing Record 44 of Set 10 | slave lake
# Processing Record 45 of Set 10 | aswan
# Processing Record 46 of Set 10 | hanna
# Processing Record 47 of Set 10 | tarko-sale
# Processing Record 48 of Set 10 | ilulissat
# Processing Record 49 of Set 10 | thinadhoo
# Processing Record 50 of Set 10 | lorengau
# Processing Record 1 of Set 11 | saint-joseph
# Processing Record 2 of Set 11 | salina cruz
# Processing Record 3 of Set 11 | muros
# Processing Record 4 of Set 11 | vagay
# Processing Record 5 of Set 11 | biloela
# Processing Record 6 of Set 11 | port macquarie
# Processing Record 7 of Set 11 | saint-georges
# Processing Record 8 of Set 11 | ellisras
# Processing Record 9 of Set 11 | nguiu
# City not found. Skipping... 'coord'
# Processing Record 10 of Set 11 | sumbe
# Processing Record 11 of Set 11 | waslala
# Processing Record 12 of Set 11 | kotido
# Processing Record 13 of Set 11 | sola
# Processing Record 14 of Set 11 | dossor
# Processing Record 15 of Set 11 | mardin
# Processing Record 16 of Set 11 | shatsk
# Processing Record 17 of Set 11 | zolotinka
# City not found. Skipping... 'coord'
# Processing Record 18 of Set 11 | seymchan
# Processing Record 19 of Set 11 | porto novo
# Processing Record 20 of Set 11 | meadow lake
# Processing Record 21 of Set 11 | dawlatabad
# Processing Record 22 of Set 11 | aksarka
# Processing Record 23 of Set 11 | belyy yar
# Processing Record 24 of Set 11 | katsuura
# Processing Record 25 of Set 11 | half moon bay
# Processing Record 26 of Set 11 | tazovskiy
# Processing Record 27 of Set 11 | ugoofaaru
# Processing Record 28 of Set 11 | kenai
# Processing Record 29 of Set 11 | nouadhibou
# Processing Record 30 of Set 11 | walvis bay
# Processing Record 31 of Set 11 | coihueco
# Processing Record 32 of Set 11 | macatuba
# Processing Record 33 of Set 11 | dekar
# Processing Record 34 of Set 11 | palmas
# Processing Record 35 of Set 11 | bialogard
# Processing Record 36 of Set 11 | ulaangom
# Processing Record 37 of Set 11 | gigmoto
# Processing Record 38 of Set 11 | presidencia roque saenz pena
# Processing Record 39 of Set 11 | nador
# Processing Record 40 of Set 11 | moron
# Processing Record 41 of Set 11 | phan thiet
# Processing Record 42 of Set 11 | kvam
# Processing Record 43 of Set 11 | huzhou
# Processing Record 44 of Set 11 | ahipara
# Processing Record 45 of Set 11 | charters towers
# Processing Record 46 of Set 11 | myanaung
# Processing Record 47 of Set 11 | champerico
# Processing Record 48 of Set 11 | abu samrah
# Processing Record 49 of Set 11 | grand river south east
# City not found. Skipping... 'coord'
# Processing Record 50 of Set 11 | whithorn
# Processing Record 1 of Set 12 | omaruru
# Processing Record 2 of Set 12 | sinnamary
# Processing Record 3 of Set 12 | georgetown
# Processing Record 4 of Set 12 | tromso
# Processing Record 5 of Set 12 | kuala sungai baru
# Processing Record 6 of Set 12 | bhadrachalam
# Processing Record 7 of Set 12 | darnah
# Processing Record 8 of Set 12 | rahuri
# Processing Record 9 of Set 12 | yichun
# Processing Record 10 of Set 12 | carutapera
# Processing Record 11 of Set 12 | kampot
# Processing Record 12 of Set 12 | yanan
# City not found. Skipping... 'coord'
# Processing Record 13 of Set 12 | portobelo
# Processing Record 14 of Set 12 | eyl
# Processing Record 15 of Set 12 | nevers
# Processing Record 16 of Set 12 | tombouctou
# Processing Record 17 of Set 12 | princeton
# Processing Record 18 of Set 12 | melfi
# Processing Record 19 of Set 12 | chara
# Processing Record 20 of Set 12 | chaihe
# Processing Record 21 of Set 12 | quelimane
# Processing Record 22 of Set 12 | ixtapa
# Processing Record 23 of Set 12 | akdepe
# Processing Record 24 of Set 12 | caramay
# Processing Record 25 of Set 12 | honningsvag
# Processing Record 26 of Set 12 | umba
# Processing Record 27 of Set 12 | gizo
# Processing Record 28 of Set 12 | trairi
# Processing Record 29 of Set 12 | mahanje
# Processing Record 30 of Set 12 | mogadishu
# Processing Record 31 of Set 12 | katsiveli
# City not found. Skipping... 'coord'
# Processing Record 32 of Set 12 | mingoyo
# Processing Record 33 of Set 12 | vryburg
# Processing Record 34 of Set 12 | paita
# Processing Record 35 of Set 12 | umm kaddadah
# Processing Record 36 of Set 12 | liwale
# Processing Record 37 of Set 12 | saint-francois
# Processing Record 38 of Set 12 | san policarpo
# Processing Record 39 of Set 12 | dudinka
# Processing Record 40 of Set 12 | clifton
# Processing Record 41 of Set 12 | saint-denis
# Processing Record 42 of Set 12 | kautokeino
# Processing Record 43 of Set 12 | bentiu
# Processing Record 44 of Set 12 | youghal
# Processing Record 45 of Set 12 | calabar
# Processing Record 46 of Set 12 | goma
# Processing Record 47 of Set 12 | wejherowo
# Processing Record 48 of Set 12 | beringovskiy
# Processing Record 49 of Set 12 | henties bay
# Processing Record 50 of Set 12 | yunjinghong
# City not found. Skipping... 'coord'
# Processing Record 1 of Set 13 | artyk
# City not found. Skipping... 'coord'
# Processing Record 2 of Set 13 | coahuayana
# Processing Record 3 of Set 13 | russell
# Processing Record 4 of Set 13 | severnoye
# Processing Record 5 of Set 13 | xinye
# Processing Record 6 of Set 13 | mwinilunga
# Processing Record 7 of Set 13 | ingham
# Processing Record 8 of Set 13 | naryan-mar
# Processing Record 9 of Set 13 | kawalu
# Processing Record 10 of Set 13 | bagdarin
# Processing Record 11 of Set 13 | mayo
# Processing Record 12 of Set 13 | qasigiannguit
# Processing Record 13 of Set 13 | camalu
# Processing Record 14 of Set 13 | makakilo city
# Processing Record 15 of Set 13 | ban nahin
# Processing Record 16 of Set 13 | necochea
# Processing Record 17 of Set 13 | scarborough
# Processing Record 18 of Set 13 | ambilobe
# Processing Record 19 of Set 13 | fort nelson
# Processing Record 20 of Set 13 | gberia fotombu
# Processing Record 21 of Set 13 | la asuncion
# Processing Record 22 of Set 13 | yartsevo
# Processing Record 23 of Set 13 | qarchi gak
# Processing Record 24 of Set 13 | esfarayen
# Processing Record 25 of Set 13 | kuli
# Processing Record 26 of Set 13 | yeppoon
# Processing Record 27 of Set 13 | kamenka
# Processing Record 28 of Set 13 | sisimiut
# Processing Record 29 of Set 13 | chum phae
# Processing Record 30 of Set 13 | pangnirtung
# Processing Record 31 of Set 13 | turochak
# Processing Record 32 of Set 13 | ogulin
# Processing Record 33 of Set 13 | northam
# Processing Record 34 of Set 13 | mizan teferi
# Processing Record 35 of Set 13 | council bluffs
# Processing Record 36 of Set 13 | aldan
# Processing Record 37 of Set 13 | lakes entrance
# Processing Record 38 of Set 13 | hondo
# Processing Record 39 of Set 13 | lokosovo
# Processing Record 40 of Set 13 | porkhov
# Processing Record 41 of Set 13 | phan rang
# City not found. Skipping... 'coord'
# Processing Record 42 of Set 13 | rosario
# Processing Record 43 of Set 13 | tank
# Processing Record 44 of Set 13 | ascension
# Processing Record 45 of Set 13 | kushiro
# Processing Record 46 of Set 13 | nara
# Processing Record 47 of Set 13 | sambava
# Processing Record 48 of Set 13 | sao joao da barra
# Processing Record 49 of Set 13 | waipawa
# Processing Record 50 of Set 13 | ampanihy
# Processing Record 1 of Set 14 | pandharpur
# Processing Record 2 of Set 14 | sabla
# Processing Record 3 of Set 14 | banikoara
# Processing Record 4 of Set 14 | puerto madero
# Processing Record 5 of Set 14 | dawei
# Processing Record 6 of Set 14 | vaitupu
# City not found. Skipping... 'coord'
# Processing Record 7 of Set 14 | kabalo
# Processing Record 8 of Set 14 | japoata
# Processing Record 9 of Set 14 | ponedera
# Processing Record 10 of Set 14 | ulaanbaatar
# Processing Record 11 of Set 14 | bubaque
# Processing Record 12 of Set 14 | vostok
# Processing Record 13 of Set 14 | wanning
# Processing Record 14 of Set 14 | port blair
# Processing Record 15 of Set 14 | santa rosa
# Processing Record 16 of Set 14 | babu
# Processing Record 17 of Set 14 | altar
# Processing Record 18 of Set 14 | kupang
# Processing Record 19 of Set 14 | gamba
# Processing Record 20 of Set 14 | tambun
# Processing Record 21 of Set 14 | huntsville
# Processing Record 22 of Set 14 | hauknes
# Processing Record 23 of Set 14 | vallenar
# Processing Record 24 of Set 14 | sai buri
# Processing Record 25 of Set 14 | podporozhye
# Processing Record 26 of Set 14 | omsukchan
# Processing Record 27 of Set 14 | badvel
# Processing Record 28 of Set 14 | nasrullaganj
# City not found. Skipping... 'coord'
# Processing Record 29 of Set 14 | tecoanapa
# Processing Record 30 of Set 14 | sungai besar
# Processing Record 31 of Set 14 | brigantine
# Processing Record 32 of Set 14 | karakendzha
# City not found. Skipping... 'coord'
# Processing Record 33 of Set 14 | puerto del rosario
# Processing Record 34 of Set 14 | saint anthony
# Processing Record 35 of Set 14 | uruzgan
# Processing Record 36 of Set 14 | bouna
# Processing Record 37 of Set 14 | kieta
# Processing Record 38 of Set 14 | smithers
# Processing Record 39 of Set 14 | pandan
# Processing Record 40 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 14 | yerbogachen
# Processing Record 42 of Set 14 | manokwari
# Processing Record 43 of Set 14 | adrar
# Processing Record 44 of Set 14 | alofi
# Processing Record 45 of Set 14 | nongan
# Processing Record 46 of Set 14 | ngunguru
# Processing Record 47 of Set 14 | vila franca do campo
# Processing Record 48 of Set 14 | cooma
# Processing Record 49 of Set 14 | bermejo
# Processing Record 50 of Set 14 | aripuana
# Processing Record 1 of Set 15 | itarema
# Processing Record 2 of Set 15 | brande
# Processing Record 3 of Set 15 | pyshma
# Processing Record 4 of Set 15 | hoopstad
# Processing Record 5 of Set 15 | ballina
# Processing Record 6 of Set 15 | cedar falls
# Processing Record 7 of Set 15 | joshimath
# Processing Record 8 of Set 15 | rundu
# Processing Record 9 of Set 15 | havre-saint-pierre
# Processing Record 10 of Set 15 | tibacuy
# Processing Record 11 of Set 15 | bitkine
# Processing Record 12 of Set 15 | yima
# Processing Record 13 of Set 15 | bonavista
# Processing Record 14 of Set 15 | mollendo
# Processing Record 15 of Set 15 | zhicheng
# Processing Record 16 of Set 15 | san felipe
# Processing Record 17 of Set 15 | yuancheng
# Processing Record 18 of Set 15 | karad
# Processing Record 19 of Set 15 | zwedru
# Processing Record 20 of Set 15 | caete
# Processing Record 21 of Set 15 | nelson bay
# Processing Record 22 of Set 15 | marsh harbour
# Processing Record 23 of Set 15 | palembang
# Processing Record 24 of Set 15 | colorado springs
# Processing Record 25 of Set 15 | padang
# Processing Record 26 of Set 15 | lima
# Processing Record 27 of Set 15 | playas
# Processing Record 28 of Set 15 | kiama
# Processing Record 29 of Set 15 | goreloye
# Processing Record 30 of Set 15 | farafangana
# Processing Record 31 of Set 15 | hambantota
# Processing Record 32 of Set 15 | santa cruz
# Processing Record 33 of Set 15 | bose
# Processing Record 34 of Set 15 | asyut
# Processing Record 35 of Set 15 | dwarka
# Processing Record 36 of Set 15 | mujiayingzi
# Processing Record 37 of Set 15 | isola della scala
# Processing Record 38 of Set 15 | atar
# Processing Record 39 of Set 15 | ankara
# Processing Record 40 of Set 15 | blagoyevo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Severo-Kurilsk  50.6789  156.1250     28.76        70          90
# 1            Vanimo  -2.6741  141.3028     76.95        92         100
# 2            Harper   4.3750   -7.7169     79.95        80          48
# 3           Iqaluit  63.7506  -68.5145     -9.56        97          46
# 4         Ostrovnoy  68.0531   39.5131     16.75        94         100
# 5          Chumikan  54.7183  135.3150    -14.44        92         100
# 6             Kapaa  22.0752 -159.3190     78.78        73          90
# 7           Rikitea -23.1203 -134.9692     77.68        73         100
# 8  Praia Da Vitoria  38.7333  -27.0667     61.75        82          40
# 9         Busselton -33.6500  115.3333     83.05        41          54
#
#    Wind Speed Country Current Description
# 0       26.51      RU     overcast clouds
# 1        9.75      PG     overcast clouds
# 2        4.43      LR    scattered clouds
# 3        3.38      CA    scattered clouds
# 4        5.44      RU          light snow
# 5       18.43      RU     overcast clouds
# 6        4.00      US          light rain
# 7        7.18      PF     overcast clouds
# 8       30.00      PT    scattered clouds
# 9        3.53      AU       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0    Severo-Kurilsk      RU  50.6789  156.1250     28.76        70
# 1            Vanimo      PG  -2.6741  141.3028     76.95        92
# 2            Harper      LR   4.3750   -7.7169     79.95        80
# 3           Iqaluit      CA  63.7506  -68.5145     -9.56        97
# 4         Ostrovnoy      RU  68.0531   39.5131     16.75        94
# 5          Chumikan      RU  54.7183  135.3150    -14.44        92
# 6             Kapaa      US  22.0752 -159.3190     78.78        73
# 7           Rikitea      PF -23.1203 -134.9692     77.68        73
# 8  Praia Da Vitoria      PT  38.7333  -27.0667     61.75        82
# 9         Busselton      AU -33.6500  115.3333     83.05        41
#
#    Cloudiness  Wind Speed Current Description
# 0          90       26.51     overcast clouds
# 1         100        9.75     overcast clouds
# 2          48        4.43    scattered clouds
# 3          46        3.38    scattered clouds
# 4         100        5.44          light snow
# 5         100       18.43     overcast clouds
# 6          90        4.00          light rain
# 7         100        7.18     overcast clouds
# 8          40       30.00    scattered clouds
# 9          54        3.53       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
